# %%
import json
import os

import pandas as pd
from gensim.models import KeyedVectors
from nodevectors import ProNE, Glove, GGVec

# %%
word_vectors = KeyedVectors.load_word2vec_format("data/colex_embeddings/clics_node2vec_embeddings", binary=False)

# %%
word_vectors["0"]
# Out:
# array([-0.02047994,  0.05916424,  0.20519084, -0.3105172 ,  0.16588277,
#        -1.0919931 ,  0.2553862 ,  0.666562  , -0.46283624,  0.43598193,
#        -0.05534175, -0.56868917, -0.13260768, -0.26992664,  0.05205116,
#        -0.3607125 ,  0.13472432, -0.50320816, -0.20322326, -0.419984  ,
#         0.14175324,  0.2873209 , -0.03548029, -0.68048465,  0.45879516,
#         0.92322433, -0.4175724 , -0.4252096 , -0.671687  ,  0.07446837,
#         0.18522488,  0.50527734,  0.25406852, -0.13428748, -0.40946656,
#        -0.2687254 , -0.16756059, -0.66990787, -0.67280316, -0.5126048 ,
#        -0.46065453, -0.04142022, -0.32780153, -0.12089379,  0.07880938,
#        -0.17406897,  0.4083    , -0.7078555 , -0.25423497,  0.5606548 ,
#         0.5153306 , -0.42795762, -0.4156445 ,  0.70552844,  0.0909841 ,
#        -0.5457586 , -0.18857387, -0.3339893 , -0.33302993,  0.02607498,
#         0.6861821 ,  0.37163094, -0.23359749, -0.02251102, -1.121223  ,
#         0.30505878,  0.02470319, -0.00456789, -0.46862364,  0.450094  ,
#        -1.0500314 , -0.26865628, -0.13860966,  0.11994141,  0.95644474,
#         0.724225  , -0.47708365,  0.57539886, -0.1537864 ,  0.53513014,
#         0.61647457, -0.00715718, -0.685666  ,  0.456122  , -0.10055106,
#         0.5329047 , -0.08014269,  0.61110985,  0.5413567 , -0.05209717,
#        -0.35410208,  0.09365551,  0.03101638, -0.10103758,  0.4332543 ,
#         0.669686  ,  0.15193881,  0.34848407, -0.5749598 , -0.02338754,
#         0.50899166,  0.56171846,  0.4463862 ,  0.07465604, -0.5679966 ,
#        -0.32383192,  0.04700675,  0.33616218, -0.4331026 , -0.37580428,
#        -0.47670472, -0.74215376, -0.24636376,  0.48043162,  0.13450141,
#         0.206675  , -0.05904246, -0.3750676 , -0.0388193 , -0.31883803,
#        -0.13558055,  0.10620828, -0.0427265 , -0.5925408 ,  0.09696399,
#         0.21866594, -1.1723989 , -0.43726236,  0.31002668,  0.13695759,
#         0.1642017 ,  0.791476  ,  0.4551055 , -0.4903724 , -0.01365993,
#         0.6971815 ,  0.03588293, -0.4168181 , -0.8394921 , -0.8717576 ,
#        -0.32333398, -0.43024385, -0.19012417, -0.08699905,  0.33954436,
#         0.11848388,  0.6049253 ,  0.0967517 , -0.27821705, -0.48113307,
#        -0.19198872, -0.11721324,  0.28848505, -0.3689192 , -0.02939581,
#        -0.09003568,  0.85257375,  0.06224287,  0.33415264,  0.78294754,
#        -0.26563543,  0.01243654, -0.57279885,  0.3831982 , -0.83167636,
#         0.18588401,  0.09112447, -0.10392576, -0.43540448,  0.21001597,
#        -0.0419759 ,  0.04853546,  0.66015345, -0.46146438, -0.07510992,
#        -0.11857878, -0.3881285 ,  0.31779507,  0.03100684, -0.12147792,
#        -0.2278614 , -0.04971981, -0.54202497,  0.34993288,  0.6354797 ,
#        -0.02529254,  0.04116083,  0.42991388,  0.03027875,  0.6065166 ,
#         0.2131985 , -0.01357303,  0.3405364 ,  0.05060966,  0.20646895,
#         0.2567557 , -0.41248724,  0.50855154,  0.68767655, -0.1355181 ],
#       dtype=float32)

# %%
def load_model(model_name, dataset, input_folder="data/node_embeddings"):
    if model_name == "node2vec":
        filepath = os.path.join(input_folder, dataset, f"{model_name}.bin")
        return KeyedVectors.load(filepath)
    else:
        filepath = os.path.join(input_folder, dataset, f"{model_name}.zip")
        if model_name == "prone":
            return ProNE.load(filepath).model
        if model_name == "ggvc":
            return GGVec.load(filepath).model
        if model_name == "glove":
            return Glove.load(filepath).model

# %%
# !pwd
# Out:
# /Users/yiyichen/Documents/experiments/ColexGraph

# %%
model = load_model("node2vec", "clics")

# %%
df = pd.read_csv("data/edgelists/edgelists_clics.csv")

# %%
model_ggvc

# %%
node2vec_sim = []
for src, tgt in zip(df["target_id"], df["source_id"]):
    sim = model.wv.similarity(src, tgt)
    node2vec_sim.append(sim)

# %%
df["node2vec_sim"] = node2vec_sim

# %%
df[df["node2vec_sim"]>0.9]
# Out:
#       source  target  weight  target_id  source_id       source_concept  \
# 96       568     705     110        430        327  RISE (MOVE UPWARDS)
# 135     1574    1439      93        967       1078                FLOAT
# 379     1155    1667      46       1150        728                 CAVE
# 684     2113    2112      27       1395       1396           OLD (USED)
# 1496    1172    1455      12        983        739                SHOOT
# 2587    1061    1064       6        663        660               ARMOUR
# 2607    1215      78       6         45        773                 THOU
# 3485     729     679       4        409        452                 DAWN
# 4202    1489     960       3        601       1011                CLOUD
#
#       target_concept  node2vec_sim
# 96    GO UP (ASCEND)      0.987990
# 135             SWIM      0.972762
# 379             HOLE      0.999459
# 684       OLD (AGED)      0.936774
# 1496            PULL      0.936992
# 2587          SHIELD      0.998261
# 2607            THAT      0.901669
# 3485          BRIGHT      0.987455
# 4202            WIND      0.903854

# %%
name2id["EARTH (SOIL)"]
# Out:
# '1228'

# %%
model.wv.similarity(node2id[name2id["DUST"]], node2id[name2id["EARTH (SOIL)"]])
# Out:
# 0.25389394

# %%
model.wv.similarity(node2id[name2id["HARD"]], node2id[name2id["BRAVE"]])
# Out:
# 0.42228952

# %%
model.wv.similarity(1232, 565)
# Out:
# 0.36112124

# %%
name2id["HARD"]
# Out:
# '1884'

# %%
word_vectors.distance

# %%
df = pd.read_csv("data/edgelists/edgelists_clics.csv")

# %%
id2name
# Out:
# {'0': nan,
#  '1': 'CONTEMPTIBLE',
#  '2': 'DUST',
#  '3': 'BRAVE',
#  '4': 'COURTYARD',
#  '5': 'GAZELLE',
#  '6': 'EARTHQUAKE',
#  '7': 'GATHER',
#  '8': 'CURSE',
#  '9': 'ANNOUNCE',
#  '10': 'FIREWOOD',
#  '11': 'DARKNESS',
#  '12': 'MIDDAY',
#  '13': 'DECEIT',
#  '14': 'YOKE',
#  '15': 'OTTER',
#  '16': 'SLED',
#  '17': 'EYELID',
#  '18': 'EARLOBE',
#  '19': 'FISHING LINE',
#  '20': 'SCYTHE',
#  '21': 'TASTE (SOMETHING)',
#  '22': 'INTEND',
#  '23': 'RYE',
#  '24': 'PRAY',
#  '25': 'DIRT',
#  '26': 'UNPLEASANT',
#  '27': 'AIR',
#  '28': 'MOISTEN',
#  '29': 'GELD',
#  '30': 'DISPEL',
#  '31': 'PAN',
#  '32': 'EARWAX',
#  '33': 'NETTLE',
#  '34': 'STAIRS',
#  '35': 'TAMARIND',
#  '36': 'PUBIC HAIR',
#  '37': 'LIBERATE',
#  '38': 'SPREAD OUT',
#  '39': 'KEEN',
#  '40': 'ENVY',
#  '41': 'IGNORE',
#  '42': 'STINKING',
#  '43': 'LEAD (GUIDE)',
#  '44': 'INJURE',
#  '45': 'EVIL',
#  '46': 'HOLLOW OUT',
#  '47': 'EXCRETA',
#  '48': 'BE SILENT',
#  '49': 'REFUSE',
#  '50': 'JACK',
#  '51': 'SORE',
#  '52': 'SHIVER',
#  '53': 'SPIRIT',
#  '54': 'SHRINK',
#  '55': 'WHISPER',
#  '56': 'BAD LUCK',
#  '57': 'ATOP',
#  '58': 'LIQUID',
#  '59': 'ELECTRICITY',
#  '60': 'OAT',
#  '61': 'INDUCE',
#  '62': 'BE SITUATED',
#  '63': 'RUMOUR',
#  '64': 'PIN',
#  '65': 'AMBUSH',
#  '66': 'KNEEL',
#  '67': 'EMBERS',
#  '68': 'TATTOO',
#  '69': 'SOBER',
#  '70': 'BRACKISH',
#  '71': 'BY HEART',
#  '72': 'CLAW',
#  '73': 'BEAK',
#  '74': 'PUPPY',
#  '75': 'DISGRACE',
#  '76': 'YOUNG MAN',
#  '77': 'YOUNG WOMAN',
#  '78': 'THAT',
#  '79': 'WASTE',
#  '80': 'DOORPOST',
#  '81': 'FATHOM',
#  '82': 'ANGER',
#  '83': 'FORBID',
#  '84': 'JUST',
#  '85': 'GIVE BACK',
#  '86': 'SIEVE',
#  '87': 'SQUINT-EYED',
#  '88': 'BEEHIVE',
#  '89': 'NATIVE COUNTRY',
#  '90': 'INNOCENT',
#  '91': 'INSOLENT',
#  '92': 'SPOIL (SOMEBODY OR SOMETHING)',
#  '93': 'DRAW MILK',
#  '94': 'GRADUALLY',
#  '95': 'SANDFLY',
#  '96': 'CRAWL',
#  '97': 'THROUGH',
#  '98': 'ALL',
#  '99': 'HUNCHBACK',
#  '100': 'FAITHFUL',
#  '101': 'BOAST',
#  '102': 'COMMON COLD (DISEASE)',
#  '103': 'FORNICATE',
#  '104': 'HAILING',
#  '105': 'MATTRESS',
#  '106': 'SATIATED',
#  '107': 'OMEN',
#  '108': 'RUDDER',
#  '109': 'FOREIGN',
#  '110': 'MOTOR',
#  '111': 'DRUMMING',
#  '112': 'TURTLE',
#  '113': 'SHORE',
#  '114': 'PORPOISE',
#  '115': 'PROFLIGATE',
#  '116': 'LARCH',
#  '117': 'IMITATE',
#  '118': 'BEWITCH',
#  '119': 'DIVE',
#  '120': 'PITCHER',
#  '121': 'SPIN',
#  '122': 'CART',
#  '123': 'FOREHEAD',
#  '124': 'THORN',
#  '125': 'SWEAT (SUBSTANCE)',
#  '126': 'SWEAT (PERSPIRE)',
#  '127': 'EXTINGUISH',
#  '128': 'MUMBLE',
#  '129': 'CHOKE',
#  '130': 'GRATIS (OF CHARGE)',
#  '131': 'FESTIVAL',
#  '132': 'SAUCE',
#  '133': 'WEAVE',
#  '134': 'FAULT',
#  '135': 'BOOMERANG',
#  '136': 'HERE',
#  '137': 'COCA',
#  '138': 'BATHE',
#  '139': 'GUMS',
#  '140': 'PADDY FIELD',
#  '141': 'BURN (SOMETHING)',
#  '142': 'RETURN HOME',
#  '143': 'HUMID',
#  '144': 'MACHINE',
#  '145': 'SORROWFUL',
#  '146': 'SUGAR CANE',
#  '147': 'COCONUT TREE',
#  '148': 'ITCH',
#  '149': 'ITCHY',
#  '150': 'WORRY',
#  '151': 'RAZOR',
#  '152': 'HOOF',
#  '153': 'GREY',
#  '154': 'UDDER',
#  '155': 'CHOP',
#  '156': 'RED',
#  '157': 'DYE',
#  '158': 'PUT ON',
#  '159': 'SWEET POTATO',
#  '160': 'SET (HEAVENLY BODIES)',
#  '161': 'MISS (A TARGET)',
#  '162': 'HICCOUGH',
#  '163': 'BLACK',
#  '164': 'KANGAROO',
#  '165': 'WALLABY',
#  '166': 'MAINLAND',
#  '167': 'MAIL',
#  '168': 'REST',
#  '169': 'IT',
#  '170': "FATHER'S SISTER",
#  '171': "MOTHER'S SISTER",
#  '172': 'SHOULDERBLADE',
#  '173': "SIBLING'S CHILD",
#  '174': 'PROUD',
#  '175': 'BLOW (OF WIND)',
#  '176': 'BLOW (WITH MOUTH)',
#  '177': 'BETEL PEPPER VINE',
#  '178': 'RIPE',
#  '179': 'RIPEN',
#  '180': 'CALL BY NAME',
#  '181': 'ANTEATER',
#  '182': 'SPOKE',
#  '183': 'BAKE',
#  '184': 'MAST',
#  '185': 'FIREPLACE',
#  '186': 'SHIN',
#  '187': 'LOIN',
#  '188': 'COMB OF BIRD',
#  '189': 'HAIR (BODY)',
#  '190': 'MOW',
#  '191': 'NUT',
#  '192': 'CORNER',
#  '193': 'SHALLOW',
#  '194': 'FAMILY',
#  '195': 'MAT',
#  '196': 'DONATE',
#  '197': 'OTHER',
#  '198': 'GENITALIA',
#  '199': 'FAMINE',
#  '200': 'SAME',
#  '201': 'FARM',
#  '202': 'STRENGTH',
#  '203': 'MARRY',
#  '204': 'AGAIN',
#  '205': 'TROUGH',
#  '206': 'FIREFLY',
#  '207': 'SPARSE',
#  '208': 'NASAL MUCUS (SNOT)',
#  '209': 'RARE',
#  '210': 'LIFE',
#  '211': 'CAST',
#  '212': 'FIELD',
#  '213': 'FIN',
#  '214': 'STRETCH',
#  '215': 'LIE DOWN',
#  '216': 'MOVIE',
#  '217': 'BETELNUT',
#  '218': 'FINE (PENALTY)',
#  '219': 'TOILET',
#  '220': 'INTACT',
#  '221': 'FIRE',
#  '222': 'LAVISH',
#  '223': 'THRESHING-FLOOR',
#  '224': 'MORTAR',
#  '225': 'PESTLE',
#  '226': 'TELL FORTUNES',
#  '227': 'FISH',
#  '228': 'CARVE',
#  '229': 'MOVE AWAY',
#  '230': 'SWEEP',
#  '231': 'SHAVE',
#  '232': 'FLEA',
#  '233': 'SNOWSHOE',
#  '234': 'PADDLE',
#  '235': 'FLYING FOX',
#  '236': 'STEPMOTHER',
#  '237': 'STEPFATHER',
#  '238': 'PRAWNS',
#  '239': 'FLOWER',
#  '240': 'ELECTION',
#  '241': 'TREE STUMP',
#  '242': 'COST',
#  '243': 'FRESH',
#  '244': 'LEFT',
#  '245': 'BROOM',
#  '246': 'THRUST',
#  '247': 'TAN',
#  '248': 'HAPPEN',
#  '249': 'FOG',
#  '250': 'LIGHT (COLOR)',
#  '251': 'SHARPEN (SOMETHING)',
#  '252': 'FRIGHTEN',
#  '253': 'CARE FOR',
#  '254': 'STICKING',
#  '255': 'SERVANT',
#  '256': 'FOOD',
#  '257': 'WORSHIP',
#  '258': 'CALM',
#  '259': 'ROUGH (OF SEA)',
#  '260': 'SAVANNA',
#  '261': 'ARCTIC LIGHTS',
#  '262': 'HE OR SHE OR IT',
#  '263': 'HERDSMAN',
#  '264': 'HE-GOAT',
#  '265': 'FOWL',
#  '266': 'SCALE',
#  '267': 'NIT',
#  '268': 'DRIBBLE',
#  '269': 'COOKED',
#  '270': 'JUG',
#  '271': 'SAUCER',
#  '272': 'TONGS',
#  '273': 'DOUGH',
#  '274': 'KNEAD',
#  '275': 'PEEL',
#  '276': 'BANISTERIUM',
#  '277': 'SPINDLE',
#  '278': 'AWL',
#  '279': 'THATCH',
#  '280': 'RIDGEPOLE',
#  '281': 'POST',
#  '282': 'POLE',
#  '283': 'PADDY',
#  '284': 'HOE',
#  '285': 'THRESH',
#  '286': 'NEEDLE TREE',
#  '287': 'CONE',
#  '288': 'FORGE',
#  '289': 'MOLD',
#  '290': 'ADZE',
#  '291': 'PULL OFF (SKIN)',
#  '292': 'RUG',
#  '293': 'NETBAG',
#  '294': 'TUMPLINE',
#  '295': 'WHETSTONE',
#  '296': 'CROUCH',
#  '297': 'CROOKED',
#  '298': 'SHRIEK',
#  '299': 'SCOLD',
#  '300': 'RATTLE',
#  '301': 'CHIEFTAIN',
#  '302': 'CLAN',
#  '303': 'ABSTAIN FROM FOOD',
#  '304': 'PREACH',
#  '305': 'GRANDPARENTS',
#  '306': 'PARENTS-IN-LAW',
#  '307': 'HAWK',
#  '308': 'TOUCAN',
#  '309': 'OPOSSUM',
#  '310': 'HEAD LOUSE',
#  '311': 'BODY LOUSE',
#  '312': 'TAPIR',
#  '313': 'AGOUTI',
#  '314': 'CAPYBARA',
#  '315': 'CURASSOW',
#  '316': 'PACA',
#  '317': 'PIRANHA',
#  '318': 'FOOTPRINT',
#  '319': 'LICK',
#  '320': 'LAME',
#  '321': 'CHEW',
#  '322': 'FIG',
#  '323': 'FAT (ORGANIC SUBSTANCE)',
#  '324': 'MANIOC FLOUR',
#  '325': 'FELT',
#  '326': 'CLOAK',
#  '327': 'PONCHO',
#  '328': 'GRASS-SKIRT',
#  '329': 'STOCKING',
#  '330': 'HEADBAND',
#  '331': 'HEADDRESS',
#  '332': 'RAG',
#  '333': 'PLAIT',
#  '334': 'COOKHOUSE',
#  '335': 'MEETING HOUSE',
#  '336': 'PADLOCK',
#  '337': 'PITCHFORK',
#  '338': 'RAKE',
#  '339': 'DIGGING STICK',
#  '340': 'LASSO',
#  '341': 'SICKLE',
#  '342': 'HAY',
#  '343': 'VINE',
#  '344': 'TREE TRUNK',
#  '345': 'SAP',
#  '346': 'BANYAN',
#  '347': 'SORGHUM',
#  '348': 'FISH POISON',
#  '349': 'ACHIOTE',
#  '350': 'MANGROVE',
#  '351': 'TARO',
#  '352': 'UNTIE',
#  '353': 'STRIKE',
#  '354': 'POUND',
#  '355': 'CUT DOWN',
#  '356': 'SHEARS',
#  '357': 'HANG UP',
#  '358': 'TINPLATE',
#  '359': 'POTTER',
#  '360': 'FAN (ACTION)',
#  '361': 'PEG',
#  '362': 'STRING',
#  '363': 'DWELL (LIVE, RESIDE)',
#  '364': 'SMEAR',
#  '365': 'SPLASH',
#  '366': 'LIMP',
#  '367': 'RIDE',
#  '368': 'SLEDGE',
#  '369': 'OWE',
#  '370': 'BARTER',
#  '371': 'PICK UP',
#  '372': 'POINTED',
#  '373': 'LONG AGO',
#  '374': 'ONE TIME',
#  '375': 'SNIFF',
#  '376': 'FRAGRANT',
#  '377': 'LOUD',
#  '378': 'PINCH',
#  '379': 'BLUNT',
#  '380': 'WRINKLED',
#  '381': 'BLAME',
#  '382': 'GOVERN',
#  '383': 'MASTER',
#  '384': 'FREEMAN',
#  '385': 'RESPECT (SOMEBODY)',
#  '386': 'BATTLE-AXE',
#  '387': 'SLING',
#  '388': 'FISHNET',
#  '389': 'FISH TRAP',
#  '390': 'PUNISHMENT',
#  '391': 'BLESS',
#  '392': 'MAGIC',
#  '393': 'CIRCUMCISION',
#  '394': 'SHAMAN (FOLK HEALER)',
#  '395': 'PILL',
#  '396': 'TABLET',
#  '397': 'BIRTH CERTIFICATE',
#  '398': 'PIERCE',
#  '399': 'PLANTAIN',
#  '400': 'MUSH',
#  '401': 'OPPRESS',
#  '402': 'SURPASS',
#  '403': 'GARDEN-HOUSE',
#  '404': 'ALCOHOL (FERMENTED DRINK)',
#  '405': 'OLDER SIBLING',
#  '406': 'OLD MAN',
#  '407': 'MANIOC BREAD',
#  '408': "MEN'S HOUSE",
#  '409': 'FORKED BRANCH',
#  '410': 'YAM',
#  '411': 'GOURD',
#  '412': 'CARRY IN HAND',
#  '413': 'CARRY ON SHOULDER',
#  '414': 'CARRY ON HEAD',
#  '415': 'CARRY UNDER ARM',
#  '416': 'OUTRIGGER',
#  '417': 'THREE TIMES',
#  '418': 'FOR A LONG TIME',
#  '419': 'SEVERE',
#  '420': 'FOREST',
#  '421': 'RETREAT',
#  '422': 'NECESSITY',
#  '423': 'GET LOST',
#  '424': 'MARRIED MAN',
#  '425': 'BE LATE',
#  '426': 'MARRIED WOMAN',
#  '427': 'YOUNGER SIBLING',
#  '428': 'BE MANY',
#  '429': 'SWIDDEN FIELD',
#  '430': 'TWIST',
#  '431': 'UPPER ARM',
#  '432': 'BLOWGUN',
#  '433': 'HOWLER MONKEY',
#  '434': 'SPIDER MONKEY',
#  '435': 'COLLARED PECCARY',
#  '436': 'WHITE-LIPPED PECCARY',
#  '437': 'GUAN',
#  '438': 'CHIGGOE (JIGGER FLEA)',
#  '439': 'CEBUS MONKEY',
#  '440': 'CHONTA PALM',
#  '441': 'CHICHA',
#  '442': 'FRONT TOOTH (INCISOR)',
#  '443': 'TIP (OF TONGUE)',
#  '444': 'LONG HAIR',
#  '445': 'UPPER BACK',
#  '446': 'LOWER ARM',
#  '447': 'LOWER LEG',
#  '448': 'STORM CLOUDS',
#  '449': 'CORN FIELD',
#  '450': 'CUSHMA',
#  '451': 'HARMATTAN',
#  '452': 'DRY SEASON',
#  '453': 'RAINY SEASON',
#  '454': 'SHEA NUT TREE',
#  '455': 'MAHOGANY TREE',
#  '456': 'GUINEA FOWL',
#  '457': 'BLIND PERSON',
#  '458': 'DEAF PERSON',
#  '459': 'SNAP (OF STICK)',
#  '460': 'BREAK (OF ROPE)',
#  '461': 'BOUBOU',
#  '462': 'WRAPPER',
#  '463': 'FELL (A TREE)',
#  '464': 'ALANG-ALANG GRASS',
#  '465': 'CARRY ON BACK',
#  '466': 'CASSOWARY',
#  '467': 'CRAYFISH',
#  '468': 'G-STRING',
#  '469': 'PANDANUS',
#  '470': 'POSSUM',
#  '471': 'UPPER LEG (THIGH)',
#  '472': 'PELICAN',
#  '473': 'SPEAR (SOMEBODY)',
#  '474': 'DRESS',
#  '475': 'UNTRUTH',
#  '476': 'CUP',
#  '477': 'LATE',
#  '478': 'LIP',
#  '479': 'GROW',
#  '480': 'PLATE',
#  '481': 'DISH',
#  '482': 'NOBLE',
#  '483': 'COMPOUND',
#  '484': 'CONDEMN',
#  '485': 'DISAPPEAR',
#  '486': 'MINISTER',
#  '487': 'SHY',
#  '488': 'MANNER',
#  '489': 'KIDNEY',
#  '490': 'DESCENDANTS',
#  '491': 'CENTER',
#  '492': 'THREE',
#  '493': 'FIVE',
#  '494': 'FLIRT',
#  '495': 'REVENGE',
#  '496': 'CUCUMBER',
#  '497': 'SCAR',
#  '498': 'CALF OF LEG',
#  '499': 'CURE',
#  '500': 'CRUEL',
#  '501': 'LIFT',
#  '502': 'NAIL (TOOL)',
#  '503': 'FROG',
#  '504': 'LEARN',
#  '505': 'PARENTS',
#  '506': 'MAIZE',
#  '507': 'MELON',
#  '508': 'PERIOD',
#  '509': 'CERTAIN',
#  '510': 'STRONG EFFECT',
#  '511': 'BAOZI',
#  '512': 'SEE A DOCTOR',
#  '513': 'THIS YEAR',
#  '514': 'LAST YEAR',
#  '515': 'NEXT YEAR',
#  '516': 'PERSON (CLASSIFIER)',
#  '517': 'FIREDRILL',
#  '518': 'SPARK',
#  '519': 'SPOT',
#  '520': 'MANZANITA',
#  '521': 'TULE',
#  '522': 'WOLF',
#  '523': 'BACK OF HEAD',
#  '524': 'BARBEL',
#  '525': 'BLOOD VESSEL',
#  '526': 'HOWL',
#  '527': 'DOG-ROSE',
#  '528': 'DREADFUL',
#  '529': 'FLANK',
#  '530': 'FRECKLE',
#  '531': 'HOW MUCH',
#  '532': 'GIPSY',
#  '533': 'GLUTTON',
#  '534': 'HUMP',
#  '535': 'INFLATED',
#  '536': 'LOW VOICE',
#  '537': 'TURBID',
#  '538': 'MULTITUDE',
#  '539': 'NEST',
#  '540': 'PALATE',
#  '541': 'POETRY',
#  '542': 'SCANTY',
#  '543': 'SHUTTLE',
#  '544': 'SPICY',
#  '545': 'SPRUCE',
#  '546': 'SUCKER',
#  '547': 'SURFACE',
#  '548': 'INFECTED',
#  '549': 'COPULATE',
#  '550': 'DILUTE',
#  '551': 'DISLOCATE',
#  '552': 'GROW UP',
#  '553': 'HEW',
#  '554': 'HINDER',
#  '555': 'INFRINGE',
#  '556': 'MARRY OFF',
#  '557': 'OFFEND',
#  '558': 'PASS BY',
#  '559': 'BROTHER (OF MAN)',
#  '560': 'BROTHER (OF WOMAN)',
#  '561': 'SISTER (OF MAN)',
#  '562': 'SISTER (OF WOMAN)',
#  '563': 'YOUNG (OF WOMAN)',
#  '564': 'YOUNG (OF MAN)',
#  '565': 'OLD (OF MAN)',
#  '566': 'OLD (OF WOMAN)',
#  '567': 'REBEL',
#  '568': 'RISE (MOVE UPWARDS)',
#  '569': 'SPOIL (BECOME SPOILED)',
#  '570': 'STAND UP',
#  '571': 'STING',
#  '572': 'STREW',
#  '573': 'SWAY',
#  '574': 'TRANSIT',
#  '575': 'TREAD',
#  '576': 'DANDRUFF',
#  '577': 'FOREFINGER',
#  '578': 'KISS',
#  '579': 'BATTLE',
#  '580': 'FUR',
#  '581': 'COME BACK',
#  '582': 'LEND',
#  '583': 'KIND OR POLITE',
#  '584': 'DIFFICULT',
#  '585': 'BOOT',
#  '586': 'GARDEN',
#  '587': 'ANT',
#  '588': 'BROKEN',
#  '589': 'CLOSED',
#  '590': 'NAKED',
#  '591': 'ADDRESS',
#  '592': 'PISS',
#  '593': 'POTATO',
#  '594': 'PIECE',
#  '595': 'GROUNDNUT (PEANUT)',
#  '596': 'POSTAGE STAMP',
#  '597': 'PHYSICIAN',
#  '598': 'SHELL',
#  '599': "DRIVER'S LICENSE",
#  '600': 'STRANGE',
#  '601': 'LIE (MISLEAD)',
#  '602': 'HIDE (CONCEAL)',
#  '603': 'COAT',
#  '604': 'GLASS',
#  '605': 'GRAIN',
#  '606': 'GRASS',
#  '607': 'GRASSHOPPER',
#  '608': 'GULF',
#  '609': 'HAIL',
#  '610': 'PORT',
#  '611': 'HARVEST',
#  '612': 'HEAT',
#  '613': 'HIGH TIDE',
#  '614': 'HILL',
#  '615': 'HORSE',
#  '616': 'HOSPITAL',
#  '617': 'ICE',
#  '618': 'PRECIPICE',
#  '619': 'ANIMAL',
#  '620': 'INSECT',
#  '621': 'IRON',
#  '622': 'ISLAND',
#  '623': 'LAGOON',
#  '624': 'LAKE',
#  '625': 'LAMP',
#  '626': 'LAND',
#  '627': 'LEAD (CHEMICAL ELEMENT)',
#  '628': 'LEAF',
#  '629': 'LEATHER',
#  '630': 'LIGHT (RADIATION)',
#  '631': 'LIVESTOCK',
#  '632': 'LIZARD',
#  '633': 'MARKET',
#  '634': 'MEAT',
#  '635': 'MILK',
#  '636': 'MILL',
#  '637': 'MOSS',
#  '638': 'MOTORCYCLE',
#  '639': 'MOUNTAIN',
#  '640': 'MUD',
#  '641': 'MUSHROOM',
#  '642': 'MUSIC',
#  '643': 'NEED (NOUN)',
#  '644': 'OAK',
#  '645': 'OCEAN',
#  '646': 'ASH',
#  '647': 'PAINT (PIGMENTS)',
#  '648': 'PAPER',
#  '649': 'PASTURE',
#  '650': 'PETROLEUM',
#  '651': 'SEAL',
#  '652': 'PLAIN',
#  '653': 'PLANT (VEGETATION)',
#  '654': 'PLASTIC',
#  '655': 'POISON',
#  '656': 'POLICE',
#  '657': 'PRICE',
#  '658': 'RAIN (PRECIPITATION)',
#  '659': 'REED',
#  '660': 'REEF',
#  '661': 'RELIGION',
#  '662': 'BATTERY',
#  '663': 'BAY',
#  '664': 'RESIN',
#  '665': 'BEE',
#  '666': 'RIVER',
#  '667': 'ROAD',
#  '668': 'ROCK',
#  '669': 'RODENT',
#  '670': 'ROOT',
#  '671': 'SAND',
#  '672': 'EARLY',
#  '673': 'SCHOOL',
#  '674': 'MOUTH',
#  '675': 'FAECES (EXCREMENT)',
#  '676': 'SHIT (DEFECATE)',
#  '677': 'AXE',
#  '678': 'BEARD',
#  '679': 'BRIGHT',
#  '680': 'BREAK (DESTROY OR GET DESTROYED)',
#  '681': 'DESTROY',
#  '682': 'SIDE',
#  '683': 'PERSON',
#  '684': 'OWN',
#  '685': 'DECIDE',
#  '686': 'EASY',
#  '687': 'NOTHING',
#  '688': 'LUNG',
#  '689': 'BETWEEN',
#  '690': 'BOTTOM',
#  '691': 'SEASON',
#  '692': 'BRING',
#  '693': 'FROM',
#  '694': 'GET',
#  '695': 'GO',
#  '696': 'STIR',
#  '697': 'CONTAIN',
#  '698': 'WISE',
#  '699': 'SAD',
#  '700': 'CARRY',
#  '701': 'SLOW',
#  '702': 'CATCH',
#  '703': 'SOON',
#  '704': 'CLEAN',
#  '705': 'GO UP (ASCEND)',
#  '706': 'DARK',
#  '707': 'REMEMBER',
#  '708': 'SHINE',
#  '709': 'TEACH',
#  '710': 'WHEEL',
#  '711': 'TALL',
#  '712': 'RICH',
#  '713': 'STEAL',
#  '714': 'SEED',
#  '715': 'SHOUT',
#  '716': 'GROAN',
#  '717': 'SWEET',
#  '718': 'PAY',
#  '719': 'FIND',
#  '720': 'GOOD LUCK',
#  '721': 'LOW',
#  '722': 'ATTACK',
#  '723': 'PLACE (POSITION)',
#  '724': 'READ',
#  '725': 'OLD PERSON',
#  '726': 'WHILE',
#  '727': 'WHICH',
#  '728': 'FIRST',
#  '729': 'DAWN',
#  '730': 'SNAKE',
#  '731': 'BEVERAGE',
#  '732': 'YOUR (SINGULAR)',
#  '733': 'EARN',
#  '734': 'MAKE',
#  '735': 'OWL',
#  '736': 'YARD',
#  '737': 'LIGHT (IGNITE)',
#  '738': 'THING',
#  '739': 'FEED',
#  '740': 'SHIP',
#  '741': 'DRIVE',
#  '742': 'END (OF SPACE)',
#  '743': 'END (OF TIME)',
#  '744': 'EGG',
#  '745': 'SHELF',
#  '746': 'SHOP',
#  '747': 'BICYCLE',
#  '748': 'SOW SEEDS',
#  '749': 'ENTER',
#  '750': 'DROP',
#  '751': 'SHRUB',
#  '752': 'STORE',
#  '753': 'PUPIL (STUDENT)',
#  '754': 'HURRY',
#  '755': 'DENY',
#  '756': 'DEPEND',
#  '757': 'BUTTON',
#  '758': 'HERON',
#  '759': 'SILVER',
#  '760': 'KNOT',
#  '761': 'COVER',
#  '762': 'OUTSIDE',
#  '763': 'SKIN',
#  '764': 'SUIT',
#  '765': 'MOVE',
#  '766': 'MENSTRUATION',
#  '767': 'CORPSE',
#  '768': 'LUNCH',
#  '769': 'ROOF',
#  '770': 'EARRING',
#  '771': 'HAT',
#  '772': 'BELT',
#  '773': 'HAVE',
#  '774': 'CABBAGE',
#  '775': 'TRUMPET',
#  '776': 'TRUNK OF TREE',
#  '777': 'FLUTE',
#  '778': 'SMOKE (EXHAUST)',
#  '779': 'PART',
#  '780': 'OUR',
#  '781': 'FEAR (FRIGHT)',
#  '782': 'DEFEAT',
#  '783': 'VICTORY',
#  '784': 'SNOW',
#  '785': 'STRONG',
#  '786': 'SAILCLOTH',
#  '787': 'SAIL',
#  '788': 'SOAP',
#  '789': 'PEOPLE',
#  '790': 'READY',
#  '791': 'STRANGER',
#  '792': 'BOIL (OF LIQUID)',
#  '793': 'BOIL (OF SKIN)',
#  '794': 'PEN',
#  '795': 'TROUT',
#  '796': 'NIPPLE',
#  '797': 'TESTICLES',
#  '798': 'JAW',
#  '799': 'WRIST',
#  '800': 'THIGH',
#  '801': 'RIB',
#  '802': "ADAM'S APPLE",
#  '803': 'ANKLE',
#  '804': 'WOMB',
#  '805': 'SPINE',
#  '806': 'BLANKET',
#  '807': 'SKILLED',
#  '808': 'DRIP (FALL IN GLOBULES)',
#  '809': 'TROUSERS',
#  '810': 'LOCUST',
#  '811': 'SOUL',
#  '812': 'SLAVE',
#  '813': 'DO',
#  '814': 'DRESS UP',
#  '815': 'GOVERNMENT',
#  '816': 'HALF',
#  '817': 'THEY',
#  '818': 'WILLOW',
#  '819': 'STOMACH',
#  '820': 'LAMB',
#  '821': 'POPLAR',
#  '822': 'HOW MANY',
#  '823': 'SORCERER',
#  '824': 'WITCH',
#  '825': 'AWAKE',
#  '826': 'BRANCH (BIFURCATION)',
#  '827': 'ROLL',
#  '828': 'RACCOON',
#  '829': 'RAFTER',
#  '830': 'SOOT',
#  '831': 'BASE',
#  '832': 'BEAN',
#  '833': 'ENDURE',
#  '834': 'BUTTOCKS',
#  '835': 'CHAPTER',
#  '836': 'SCREWDRIVER',
#  '837': 'BLUE',
#  '838': 'REMAINS',
#  '839': 'ERR',
#  '840': 'CORMORANT',
#  '841': 'FISHING SPEAR',
#  '842': 'LIQUOR',
#  '843': 'SPIDER',
#  '844': 'KIND (THING)',
#  '845': 'MURDER',
#  '846': 'TIGER',
#  '847': 'THIRSTY',
#  '848': 'THIRST',
#  '849': 'SPRING (OF WATER)',
#  '850': 'SQUARE',
#  '851': 'STABLE',
#  '852': 'PRIEST',
#  '853': 'ALTAR',
#  '854': 'KETTLE',
#  '855': 'SEIZE',
#  '856': 'HIRE',
#  '857': 'STONE',
#  '858': 'STORM',
#  '859': 'STOVE',
#  '860': 'CAUSE',
#  '861': 'JUDGE',
#  '862': 'SUGAR',
#  '863': 'EDGE',
#  '864': 'PUMPKIN',
#  '865': 'FAME',
#  '866': 'WIN',
#  '867': 'GLOVE',
#  '868': 'BANANA',
#  '869': 'BLADE',
#  '870': 'BREATH',
#  '871': 'RATTLESNAKE',
#  '872': 'TAR',
#  '873': 'TAX',
#  '874': 'CANDY',
#  '875': 'SHOEMAKER',
#  '876': 'ARCH',
#  '877': 'MASON',
#  '878': 'HELL',
#  '879': 'COUGH',
#  '880': 'REPEAT',
#  '881': 'TAILOR',
#  '882': 'PARROT',
#  '883': 'TERMITE',
#  '884': 'SHARE',
#  '885': 'OPPOSITE',
#  '886': 'PARAKEET',
#  '887': 'BITTER',
#  '888': 'POISONOUS',
#  '889': 'FLAME',
#  '890': 'MULE',
#  '891': 'TIDE',
#  '892': 'TIME',
#  '893': 'TIN (METAL)',
#  '894': 'TOAD',
#  '895': 'TORTOISE',
#  '896': 'ANACONDA (WATER BOA)',
#  '897': 'SWALLOW',
#  '898': 'TRADE',
#  '899': 'PRESIDENT',
#  '900': 'TRAIN',
#  '901': 'ADOBE',
#  '902': 'ADULTERY',
#  '903': 'ASPEN',
#  '904': 'BERRY',
#  '905': 'BORING',
#  '906': 'TREE',
#  '907': 'OLD WOMAN',
#  '908': 'DRUM',
#  '909': 'GARBAGE',
#  '910': 'DEATH',
#  '911': 'TEMPLE',
#  '912': 'COYOTE',
#  '913': 'CROW',
#  '914': 'SCULPTOR',
#  '915': 'SINK (BASIN)',
#  '916': 'LINEN',
#  '917': 'ORNAMENT',
#  '918': 'INCLINATION',
#  '919': 'CHILI PEPPER',
#  '920': 'GRAPE',
#  '921': 'VALLEY',
#  '922': 'PEAR',
#  '923': 'LOVE',
#  '924': 'VEGETABLES',
#  '925': 'CASSAVA',
#  '926': 'RICE',
#  '927': 'MANIOC',
#  '928': 'EMBRACE',
#  '929': 'VERMIN',
#  '930': 'VILLAGE',
#  '931': 'MILLET',
#  '932': 'BARLEY',
#  '933': 'WALL (OF HOUSE)',
#  '934': 'BUFFALO',
#  '935': 'WAR',
#  '936': 'STALLION',
#  '937': 'BIRD',
#  '938': 'MARE',
#  '939': 'HORN (INSTRUMENT)',
#  '940': 'STRAIN',
#  '941': 'MEAD',
#  '942': 'HONEY',
#  '943': 'WATERFALL',
#  '944': 'SALMON',
#  '945': 'SPEAR',
#  '946': 'BLOOD',
#  '947': 'STREAM',
#  '948': 'WATER',
#  '949': 'WATER LEECH',
#  '950': 'SEAGULL',
#  '951': 'WEAPONS',
#  '952': 'WEATHER',
#  '953': 'RAPE',
#  '954': 'WELL',
#  '955': 'GREASY',
#  '956': 'FLEE',
#  '957': 'WHALE',
#  '958': 'WILD ANIMAL',
#  '959': 'WAGON',
#  '960': 'WIND',
#  '961': 'PEBBLES',
#  '962': 'WOMAN',
#  '963': 'BOOK',
#  '964': 'WOOL',
#  '965': 'WORLD',
#  '966': 'BRAKE',
#  '967': 'YEAST',
#  '968': 'ACORN',
#  '969': 'CIGARETTE',
#  '970': 'COCONUT',
#  '971': 'MUST',
#  '972': 'BE ABLE',
#  '973': 'NOODLE',
#  '974': 'TOBACCO',
#  '975': 'SPINACH',
#  '976': 'WEAR',
#  '977': 'ARROW',
#  '978': 'WAVE',
#  '979': 'FARMER',
#  '980': 'HEEL',
#  '981': 'ELBOW',
#  '982': 'LIME (FRUIT)',
#  '983': 'CONVICT',
#  '984': 'WORK (LABOUR)',
#  '985': 'VINEGAR',
#  '986': 'TOMATO',
#  '987': 'REMAIN',
#  '988': 'ACQUIT',
#  '989': 'CLEAR',
#  '990': 'CREEK (TIDAL)',
#  '991': 'FRY',
#  '992': 'CLIFF',
#  '993': 'RIVER BED',
#  '994': 'BOW',
#  '995': 'QUIVER (FOR ARROWS)',
#  '996': 'DEAF',
#  '997': 'BAOBAB TREE',
#  '998': 'PUT',
#  '999': 'JOINT',
#  ...}

# %%
df["source_concept"] = df["source"].apply(lambda x: id2name[str(x)])
df["target_concept"] = df["target"].apply(lambda x: id2name[str(x)])

# %%
df.to_csv("data/edgelists/edgelists_clics.csv", index=False)
