# %%
# use logarithmic smoothing and bar chat.
import os
import json

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# %%
def plot_divergence_by_dataset(
        inputfile="../data/eval_nodeEmb/divergence.csv", outputfolder="../data/plots/",
):
    sns.set_theme(style="whitegrid", font_scale=1)

    df = pd.read_csv(inputfile, sep="\t")

    datasets = {"wn": "WordNet", "wn_concept": "WordNet Concept",
                "clics": "CLICS"}

    df["Dataset"].replace(datasets, inplace=True)

    df_datasets_groups = df.groupby(by=["Dataset"])

    for dataset, group in df_datasets_groups:
        print(dataset)

        plt.figure(figsize=(6, 8))

        plt.title(f"Divergence Score of Dataset {dataset}", fontsize=12)

        plt.yscale("log")  # smoothing
        plt.xticks(rotation=45)
        # plt.legend(loc="upper right")

        kg = sns.scatterplot(data=group, x="Metrics", y="Divergence", hue="Model", style="Model",size=400)
        # kg.set_title(f"Divergence Score of Dataset {dataset}")
        fig = kg.get_figure()

        fig.savefig(os.path.join(outputfolder, "divergence", f"{dataset}_div.png"))
        plt.clf()

# %%
inputfile="../data/eval_nodeEmb/divergence.csv"
sns.set_theme(style="whitegrid", font_scale=1)

df = pd.read_csv(inputfile, sep="\t")

datasets = {"wn": "WordNet", "wn_concept": "WordNet Concept",
                "clics": "CLICS"}

df["Dataset"].replace(datasets, inplace=True)

df_datasets_groups = df.groupby(by=["Dataset"])

# %%
for dataset, group in df_datasets_groups:
    print(dataset)
    sns.set_theme(style="whitegrid", font_scale=1)

    
    # plt.title(f"Divergence Score of Dataset {dataset}", fontsize=12)
    rcParams['figure.figsize'] = 11.7,10



    plt.yscale("log")  # smoothing
    plt.xticks(rotation=45)
    plt.legend(loc="upper right")

    kg =sns.scatterplot(data=group, x="Metrics", y="Divergence", hue="Model", style="Model",s=100)
    
    # kg.set_title(f"Divergence Score of Dataset {dataset}")
    fig = kg.get_figure()

    fig.savefig(os.path.join("../data/plots/", "divergence", f"{dataset}_div.png"))
    # plt.clf()
# Out:
# /var/folders/n4/_229c3094s1blstjbm14zsdw0000gn/T/ipykernel_18610/1920155482.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for dataset, group in df_datasets_groups:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# CLICS
# WordNet
# WordNet Concept
