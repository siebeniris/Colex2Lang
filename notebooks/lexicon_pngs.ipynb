# %%
import pandas as pd

import os
import json

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file = "../output/lexicon/wn_137B.csv"

# %%
df = pd.read_csv(file)

# %%
sns.set_theme(style="whitegrid")

# %%
df
# Out:
#    Test (F1)                           Value            Model  Weight
# 0   0.666667  No m in second person singular           Random    0.74
# 1   0.000000     m in second person singular           Random    0.26
# 2   0.750000  No m in second person singular          WordNet    0.74
# 3   0.500000     m in second person singular          WordNet    0.26
# 4   0.666667  No m in second person singular  WordNet Concept    0.74
# 5   0.000000     m in second person singular  WordNet Concept    0.26

# %%
# plt.figure(figsize=(12, 12))
# plt.title("Feature 137B", fontsize=18)

g= sns.relplot(data=df, x="Model", y="Test (F1)", hue="Value", size="Weight")

g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %%
# for clics, 

features_clics = ["132A", "133A", "136A", "138A"]

df_list = []
for fid in features_clics:
    file = f"../output/lexicon/clics_{fid}.csv"
    df_feature = pd.read_csv(file)
    df_list.append(df_feature)
    
df_clics = pd.concat(df_list, axis=0)

# %%
sns.relplot(data=df_clics, x="Model", y="Test (F1)", hue="Value",size="Weight", col="Feature", sizes=(100,400))
plt.savefig("../output/lexicon/clics.png")

# %%
features_wn = ["129A","132A", "133A", "137B"]

df_list_ = []
for fid in features_wn:
    file = f"../output/lexicon/wn_{fid}.csv"
    df_feature = pd.read_csv(file)
    df_list_.append(df_feature)
    
df_wn = pd.concat(df_list_, axis=0)

# %%
sns.relplot(data=df_wn, x="Model", y="Test (F1)", hue="Value",size="Weight", col="Feature", sizes=(100,400))
plt.savefig("../output/lexicon/wn.png")

# %%
b,c = df_wn

# %%
# df_wn.to_csv("../output/lexicon/wn.csv", index = False)

# %%
df_wn = pd.read_csv("../output/lexicon/wn.csv")

# %%
df_clics
# Out:
#    Test (F1)                                  Value   Model    Weight  \
# 0   0.400000                                    3.5  Random  0.638889
# 1   0.000000                                    4.5  Random  0.222222
# 2   0.500000                                    3.5   CLICS  0.638889
# 3   0.500000                                    4.5   CLICS  0.222222
# 0   0.400000                                  6-6.5  Random  0.388889
# 1   0.000000                                     11  Random  0.111111
# 2   0.666667                                  6-6.5   CLICS  0.388889
# 3   0.800000                                     11   CLICS  0.111111
# 0   0.000000                        No M-T pronouns  Random  0.729412
# 1   0.363636             M-T pronouns, paradigmatic  Random  0.235294
# 2   0.769231                        No M-T pronouns   CLICS  0.729412
# 3   0.400000             M-T pronouns, paradigmatic   CLICS  0.235294
# 0   0.777778         Words derived from Sinitic cha  Random  0.539216
# 1   0.000000  Words derived from Min Nan Chinese te  Random  0.362745
# 2   0.000000                                 Others  Random  0.098039
# 3   0.875000         Words derived from Sinitic cha   CLICS  0.539216
# 4   0.500000  Words derived from Min Nan Chinese te   CLICS  0.362745
# 5   0.000000                                 Others   CLICS  0.098039
#
#                                          Feature
# 0  Number_of_Non-Derived_Basic_Colour_Categories
# 1  Number_of_Non-Derived_Basic_Colour_Categories
# 2  Number_of_Non-Derived_Basic_Colour_Categories
# 3  Number_of_Non-Derived_Basic_Colour_Categories
# 0              Number_of_Basic_Colour_Categories
# 1              Number_of_Basic_Colour_Categories
# 2              Number_of_Basic_Colour_Categories
# 3              Number_of_Basic_Colour_Categories
# 0                                   M-T_Pronouns
# 1                                   M-T_Pronouns
# 2                                   M-T_Pronouns
# 3                                   M-T_Pronouns
# 0                                            Tea
# 1                                            Tea
# 2                                            Tea
# 3                                            Tea
# 4                                            Tea
# 5                                            Tea
